# %% [markdown]
# # Data audit
# Run `python3 src/quality_checks.py` first. This notebook profiles generated raw data.

# %%
from pathlib import Path
import pandas as pd
ROOT = Path.cwd()
if not (ROOT / 'data').exists(): ROOT = ROOT.parent
raw = ROOT / 'data' / 'raw'
frames = {p.stem: pd.read_csv(p) for p in raw.glob('*.csv')}
pd.DataFrame({'table': list(frames), 'rows': [len(x) for x in frames.values()], 'columns': [len(x.columns) for x in frames.values()]})
