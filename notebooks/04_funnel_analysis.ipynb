# %% [markdown]
# # Funnel analysis
# Session-level conversion and drop-off by event stage.

# %%
from pathlib import Path
import pandas as pd
import seaborn as sns
ROOT = Path.cwd()
if not (ROOT / 'data').exists(): ROOT = ROOT.parent
funnel = pd.read_csv(ROOT / 'data' / 'processed' / 'funnel_summary.csv')
sns.barplot(data=funnel, x='event_name', y='sessions')
